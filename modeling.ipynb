# %% [markdown]
# # Chuẩn bị dữ liệu

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Data/DelayedFlights_cleaned.csv')
df
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime CRSDepTime  ArrTime  CRSArrTime  \
# 0           1          15          2   1948.0      19:05   2248.0        2217
# 1           1          19          6    916.0      09:00   1204.0        1143
# 2           1          20          7   1403.0      13:30   1625.0        1608
# 3           1          31          4   1418.0      13:50   1810.0        1658
# 4           1           2          3   1303.0      12:30   1557.0        1445
# ...       ...         ...        ...      ...        ...      ...         ...
# 163387     12          13          6    921.0      08:30   1112.0        1008
# 163388     12          13          6   1552.0      15:20   1735.0        1718
# 163389     12          13          6   1250.0      12:20   1617.0        1552
# 163390     12          13          6    657.0      06:00    904.0         749
# 163391     12          13          6   1007.0      08:47   1149.0        1010
#
# ...
